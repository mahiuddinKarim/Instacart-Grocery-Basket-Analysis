# %% [markdown]
# ## 4.7: Deriving New Variables

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# reuseable data path
file_location = r'C:\Users\natta\Downloads\Achievement 4 project'

# %%
# importing data frame

df_orders_products_merged = pd.read_pickle(os.path.join(file_location, '02 Data', 'prepared data' , 'orders_products_merged.pkl'))

# %%
# making subset 

df = df_orders_products_merged[:1000000]

# %%
#  Define function 

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
# sort price ranges using user defined function

df['price_range'] = df.apply(price_label, axis =1 )
# Out:
# C:\Users\natta\AppData\Local\Temp\ipykernel_14564\3334714875.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis =1 )

# %%
df['price_range']
# Out:
# 0         Mid-range product
# 1         Mid-range product
# 2         Mid-range product
# 3         Mid-range product
# 4         Mid-range product
#                 ...
# 999995    Mid-range product
# 999996    Mid-range product
# 999997    Mid-range product
# 999998    Mid-range product
# 999999    Mid-range product
# Name: price_range, Length: 1000000, dtype: object

# %%
df['price_range'].value_counts (dropna = False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
## sort price ranges using .loc

df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\natta\AppData\Local\Temp\ipykernel_14564\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %% [markdown]
# ## Sort the price ranges using .loc for the whole dataframe

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_orders_products_merged.loc[(df_orders_products_merged['prices'] <= 15) & (df_orders_products_merged['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_orders_products_merged.loc[df_orders_products_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
# count the price ranges in the data frame
df_orders_products_merged['price_range_loc'].value_counts()
# Out:
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
# determine the busies days for ordering
df_orders_products_merged['orders_day_of_week'].value_counts()
# Out:
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: orders_day_of_week, dtype: int64

# %% [markdown]
# ## Define new variable using for loop

# %%
# define new variable 'busiest day' using for loop
result = []

for value in df_orders_products_merged ['orders_day_of_week']:
  if value == 0:
    result.append('Busiest day')
  elif value == 4:
    result.append('Least busy')
  else:
    result.append('Regularly busy')

# %%
df_orders_products_merged['busiest_day'] = result

# %%
df_orders_products_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: busiest_day, dtype: int64

# %%
#task 2 creating new variable 'busiest days


new_result = []

for value in df_orders_products_merged['orders_day_of_week']:
  if value == 0:
    new_result.append('Busiest_days')
  elif value == 1:
    new_result.append('Busiest_days')
  elif value == 3:
    new_result.append('Slowest_days')
  elif value ==4:
    new_result.append('Slowest_days')
  else:
    new_result.append('Regularly busy')

# %%
new_result
# Out:
# ['Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Slowest_days',
#  'Slowest_days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
#  'Regularly busy',
#  'Busiest_days',
#  'Busiest_days',
# ...

# %%
df_orders_products_merged ['Busiest_day'] = new_result

# %%
df_orders_products_merged['Busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    12916111
# Busiest_days      11864412
# Slowest_days       7624336
# Name: Busiest_day, dtype: int64

# %% [markdown]
# ##  Increase in the 'busiest_days' and 'slowest_days' after changing the range within the function

# %%
# task 4 determine the busiest hours of the day

df_orders_products_merged['order_hour_of_day'].value_counts(dropna = False)
# Out:
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: order_hour_of_day, dtype: int64

# %% [markdown]
# ## 10 am have more orders

# %%
updated_result = []

for value in df_orders_products_merged['order_hour_of_day']:
  if value > 10 & value <=18:
    updated_result.append('Most_orders')
  elif value <=5:
    updated_result.append("Fewest_orders")
  else:
    updated_result.append("Average_orders")

# %%
updated_result
# Out:
# ['Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
#  'Average_orders',
#  'Most_orders',
# ...

# %%
#Create new column name titled 'busiest_period_of_day.'

df_orders_products_merged['Busiest_period_of_day'] = updated_result

# %%
# Task 5 Print the frequency for this new column

df_orders_products_merged['Busiest_period_of_day'].value_counts(dropna = False)
# Out:
# Most_orders       27636837
# Average_orders     4479878
# Fewest_orders       288144
# Name: Busiest_period_of_day, dtype: int64

# %%
df_orders_products_merged.head()
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %%
# exporting data frame
df_orders_products_merged.to_pickle(os.path.join(file_location, '02 Data','prepared Data', 'orders_products_merged_v2.pkl'))
